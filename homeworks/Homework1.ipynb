# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 1.8 MB 2.9 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
##
# This notebook demonstrates simple attempts to manipulate Python per the instructions of the first homework.
##

# Import modules
import numpy as np
import matplotlib.pyplot as plt

# Declare list
mylist = [1, 2, 3, 4]

# Examples of basic Python functions
myarray = np.array(mylist)

myadd = np.add(myarray, 2)

mydivide = np.divide(myarray, 0.5)

# Example simple figures
plt.figure(figsize=(8,6))
plt.scatter(np.random.rand(50), np.random.rand(50), s=16, color='green')
plt.xlabel('Adding')
plt.ylabel('Dividing')
plt.title('Sample Figure')
plt.grid()
plt.show()
